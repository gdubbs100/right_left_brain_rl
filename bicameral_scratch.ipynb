# %%
class biCameralAgent:

    def __init__(self, left, right, gate):
        
        ## a neural network designed to be randomly initialised
        ## contains a policy and an encoder to conform to varibad repo
        left = self.left

        ## a pre-trained RL2 network
        ## contains a policy and an encoder to conform to varibad repo
        right = self.right

        ## some function that outputs a split of left and right
        ## could be a GRU or could be a schedule
        gate = self.gate

    def mix_dists(self, state, latent):

        ## maybe pass action params first
        left_dist = self.left.policy.dist
        left_mean = left_dist.mean
        left_std = left_dist.std

        right_dist = self.right.policy.dist
        right_mean = right_dist.mean
        right_std = right_dist.std

        ## get gating values
        gating_values = gate(some_var)

        bicam_dist = Dist(combined_right_left_mean, combined_right_left_std)

    def act(self, state, latent):
        ## latent might be left and right latents?
        if bicameral:
            self.dist = self.mix_dists(state, latent)
        elif left is not None:
            ## use left only
        elif right is not None:
            ## etc.
        
        ## do acting stuff

    def prior(self, num_processes):
        ## do prior stuff for left and right
        left.encoder.prior(num_processes)
        right.encoder.prior(num_processes)

        ## maybe gate prior
        if gate.encoder is not None:
            gate.encoder.prior(num_processes)

    def get_latents(self, state, action, reward etc):

        ## do latents for left, right and gating
